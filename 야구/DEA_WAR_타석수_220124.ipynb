# %%
import os
import pandas as pd
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression

# %%
os.chdir(r'C:\Users\jaij2\OneDrive\바탕 화면\논문\야구데이터\전처리')
df_1 = pd.read_csv('2019_144타석이상_타격지표(6개)_kWAR_19연봉, 신인제외.csv', encoding = 'cp949')
df_1 = df_1[df_1['Unnamed: 0'] != '이우성']
df_1 = df_1.reset_index(drop = True)
df_1.index = df_1['Unnamed: 0']
del df_1['Unnamed: 0']
df_1
# Out:
#               RBI    RUN    HIT    HR    SB      OPS  Money_19  kWAR_score
# Unnamed: 0
# 이정후          68.0   91.0  193.0   6.0  13.0  0.84241   23000.0     290.201
# 김하성         104.0  112.0  166.0  19.0  33.0  0.88016   32000.0     785.830
# 정은원          57.0   83.0  148.0   8.0  14.0  0.69127    5500.0     702.721
# 이천웅          48.0   88.0  168.0   2.0  21.0  0.75129   15000.0     420.339
# 최정           99.0   86.0  147.0  29.0   3.0  0.91823  120000.0     661.361
# ...           ...    ...    ...   ...   ...      ...       ...         ...
# 지석훈          15.0   15.0   34.0   2.0   0.0  0.62826   15000.0     250.270
# 허일           17.0   14.0   38.0   1.0   2.0  0.61683    3000.0      46.765
# 김찬형          12.0   16.0   39.0   1.0   3.0  0.67698    4300.0     286.502
# 나지완          17.0   12.0   24.0   6.0   0.0  0.66499   60000.0      15.600
# 최항           14.0   12.0   29.0   0.0   2.0  0.58963   11000.0     164.640
#
# [103 rows x 8 columns]

# %%
df_1.to_csv('2019_144이상_타격지표(6)_kWAR_19연봉_WAR_신인제외.csv', encoding = 'cp949')

# %%
df_2 = pd.read_csv('2019_144이상_타격지표(6)_kWAR_19연봉_WAR_신인제외.csv', encoding = 'cp949')
df_2
# Out:
#     Unnamed: 0  RBI  RUN  HIT  HR    SB      OPS  Money_19  kWAR_score   WAR
# 0          양의지   68   61  138  20   4.0  1.01227  200000.0     721.160  7.02
# 1          김하성  104  112  166  19  33.0  0.88016   32000.0     785.830  6.77
# 2           최정   99   86  147  29   3.0  0.91823  120000.0     661.361  6.63
# 3          박병호   98   92  121  33   0.0  0.95868  150000.0       0.000  5.14
# 4          이정후   68   91  193   6  13.0  0.84241   23000.0     290.201  4.81
# ..         ...  ...  ...  ...  ..   ...      ...       ...         ...   ...
# 98         윤석민   17    4   39   2   0.0  0.54837   24000.0      69.633 -0.92
# 99         김동엽   25   15   42   6   2.0  0.60386   18500.0      25.232 -0.93
# 100        오윤석   21   21   44   1   0.0  0.54212    3000.0     112.623 -0.94
# 101        최원준   18   33   46   1   8.0  0.54535   10000.0     224.517 -0.95
# 102        나종덕   13   12   23   3   0.0  0.38271    4300.0     551.103 -1.61
#
# [103 rows x 10 columns]

# %%
model = ols(formula = 'Money_19 ~ WAR', data = df_2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Money_19   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     26.43
# Date:                Mon, 24 Jan 2022   Prob (F-statistic):           1.34e-06
# Time:                        16:14:09   Log-Likelihood:                -1237.7
# No. Observations:                 103   AIC:                             2479.
# Df Residuals:                     101   BIC:                             2485.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.801e+04   5292.039      3.403      0.001    7511.761    2.85e+04
# ...

# %%
x = df_2['WAR']
y = df_2['Money_19']

LR = LinearRegression()
LR.fit(x, y)
LR.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c526731781f9> in <module>
#       3
#       4 LR = LinearRegression()
# ----> 5 LR.fit(x, y)
#       6 LR.summary()
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
df_3 = pd.read_csv('2019_타자_saber.csv', encoding = 'cp949')
df_3 = df_3[df_3['PA'] >= 144]
df_3
# Out:
#     Name   PA   AB  RBI  RUN  HIT  H2  H3  HR  SB  ...     SECA       TA  \
# 0    이정후  630  574   68   91  193  31  10   6  13  ...  0.29094  0.80397
# 1    김하성  625  540  104  112  166  38   2  19  33  ...  0.47593  0.96154
# 2    정은원  624  564   57   83  148  27   6   8  14  ...  0.28191  0.63636
# 3    이천웅  613  546   48   88  168  24   3   2  21  ...  0.24359  0.71571
# 4     최정  606  503   99   86  147  27   0  29   3  ...  0.47714  0.99171
# ..   ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ...      ...      ...
# 101  이우성  168  151   22   19   33   4   0   6   0  ...  0.29139  0.57025
# 102   허일  162  149   17   14   38   4   0   1   2  ...  0.16779  0.53097
# 103  김찬형  154  141   12   16   39   4   2   1   3  ...  0.16312  0.58879
# 104  나지완  153  129   17   12   24   5   0   6   0  ...  0.41085  0.63889
# 105   최항  147  127   14   12   29   5   0   0   2  ...  0.22047  0.53465
#
#            RC     RC27       XR      ISO       PSR     wOBA    BABIP      OW%
# ...

# %%
os.chdir(r'C:\Users\jaij2\OneDrive\바탕 화면\논문\야구데이터\수비율\전처리')
df_11 = pd.read_csv('2019_전포지션_수비점수_March_kWAR_AHP.csv', encoding = 'cp949')
df_11.index = df_11['선수명']
del df_11['선수명']
df_11
# Out:
#           IP     E  March_score  kWAR_score  AHP_score
# 선수명
# 강경학   273.00   4.0     1468.641     147.829     39.993
# 강로한   709.67  20.0     3910.467     449.717    105.735
# 강민국   245.67   9.0     1487.254     171.306     44.404
# 강민호   842.00   8.0     6661.904     832.738    308.113
# 강백호   622.66   3.0     1549.272     127.421     23.109
# ..       ...   ...          ...         ...        ...
# 홍창기    52.00   0.0      136.500      13.400      2.337
# 황대인    48.00   0.0      100.000       1.200      1.260
# 황윤호   297.67   6.0     1534.647     177.799     38.623
# 황재균  1026.67  11.0     4123.564     602.866    127.589
# 황진수    10.33   0.0       37.320       5.598      1.157
#
# [281 rows x 5 columns]

# %%
df_11
# Out:
#           IP     E  March_score  kWAR_score  AHP_score
# 선수명
# 강경학   273.00   4.0     1468.641     147.829     39.993
# 강로한   709.67  20.0     3910.467     449.717    105.735
# 강민국   245.67   9.0     1487.254     171.306     44.404
# 강민호   842.00   8.0     6661.904     832.738    308.113
# 강백호   622.66   3.0     1549.272     127.421     23.109
# ..       ...   ...          ...         ...        ...
# 홍창기    52.00   0.0      136.500      13.400      2.337
# 황대인    48.00   0.0      100.000       1.200      1.260
# 황윤호   297.67   6.0     1534.647     177.799     38.623
# 황재균  1026.67  11.0     4123.564     602.866    127.589
# 황진수    10.33   0.0       37.320       5.598      1.157
#
# [281 rows x 5 columns]

# %%
df_1['Error'] = df_11['E']
df_1
# Out:
#               RBI    RUN    HIT    HR    SB      OPS  Money_19  kWAR_score  \
# Unnamed: 0
# 이정후          68.0   91.0  193.0   6.0  13.0  0.84241   23000.0     290.201
# 김하성         104.0  112.0  166.0  19.0  33.0  0.88016   32000.0     785.830
# 정은원          57.0   83.0  148.0   8.0  14.0  0.69127    5500.0     702.721
# 이천웅          48.0   88.0  168.0   2.0  21.0  0.75129   15000.0     420.339
# 최정           99.0   86.0  147.0  29.0   3.0  0.91823  120000.0     661.361
# ...           ...    ...    ...   ...   ...      ...       ...         ...
# 지석훈          15.0   15.0   34.0   2.0   0.0  0.62826   15000.0     250.270
# 허일           17.0   14.0   38.0   1.0   2.0  0.61683    3000.0      46.765
# 김찬형          12.0   16.0   39.0   1.0   3.0  0.67698    4300.0     286.502
# 나지완          17.0   12.0   24.0   6.0   0.0  0.66499   60000.0      15.600
# 최항           14.0   12.0   29.0   0.0   2.0  0.58963   11000.0     164.640
#
#             Error
# Unnamed: 0
# 이정후           2.0
# ...

# %%
os.chdir(r'C:\Users\jaij2\OneDrive\바탕 화면\논문\야구데이터\수비율\전처리\211117')
df_1.to_csv('2019_DEA_에러포함.csv', encoding = 'cp949')

# %%
df_1['Error'] = [abs((df_1['Error'][a] - max(df_1['Error'])) / (max(df_1['Error']) - min(df_1['Error']))) for a in range(0, len(df_1['Error']))]
df_1
# Out:
#               RBI    RUN    HIT    HR    SB      OPS  Money_19  kWAR_score  \
# Unnamed: 0
# 이정후          68.0   91.0  193.0   6.0  13.0  0.84241   23000.0     290.201
# 김하성         104.0  112.0  166.0  19.0  33.0  0.88016   32000.0     785.830
# 정은원          57.0   83.0  148.0   8.0  14.0  0.69127    5500.0     702.721
# 이천웅          48.0   88.0  168.0   2.0  21.0  0.75129   15000.0     420.339
# 최정           99.0   86.0  147.0  29.0   3.0  0.91823  120000.0     661.361
# ...           ...    ...    ...   ...   ...      ...       ...         ...
# 지석훈          15.0   15.0   34.0   2.0   0.0  0.62826   15000.0     250.270
# 허일           17.0   14.0   38.0   1.0   2.0  0.61683    3000.0      46.765
# 김찬형          12.0   16.0   39.0   1.0   3.0  0.67698    4300.0     286.502
# 나지완          17.0   12.0   24.0   6.0   0.0  0.66499   60000.0      15.600
# 최항           14.0   12.0   29.0   0.0   2.0  0.58963   11000.0     164.640
#
#                Error
# Unnamed: 0
# ...

# %%
os.chdir(r'C:\Users\jaij2\OneDrive\바탕 화면\논문\야구데이터\수비율\전처리\211117')
df_1.to_csv('2019_DEA_에러포함_척도동등화.csv', encoding = 'cp949')
