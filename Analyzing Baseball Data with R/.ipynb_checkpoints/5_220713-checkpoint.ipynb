# %%
import pandas as pd
import os

# %%
os.chdir('/Users/jeongminjae/Desktop/Analyzing Baseball Data with R/baseball_R-master/data')

# %%
fields = pd.read_csv('fields.csv')
data2016 = pd.read_csv('all2016.csv', header = None)
data2016.columns = fields['Header']
data2016
# Out:
# /var/folders/j0/v712hm213nqb130pw6p8p37m0000gn/T/ipykernel_4533/4250920084.py:2: DtypeWarning: Columns (64,65,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2016 = pd.read_csv('all2016.csv', header = None)
# Header       GAME_ID AWAY_TEAM_ID  INN_CT  BAT_HOME_ID  OUTS_CT  BALLS_CT  \
# 0       ANA201604040          CHN       1            0        0         1
# 1       ANA201604040          CHN       1            0        0         0
# 2       ANA201604040          CHN       1            0        1         0
# 3       ANA201604040          CHN       1            0        2         1
# 4       ANA201604040          CHN       1            0        2         2
# ...              ...          ...     ...          ...      ...       ...
# 190710  WAS201610020          MIA       8            1        1         1
# 190711  WAS201610020          MIA       8            1        2         3
# ...

# %%
altuve = data2016[data2016['BAT_ID'] == 'altuj001']
altuve
# Out:
# Header       GAME_ID AWAY_TEAM_ID  INN_CT  BAT_HOME_ID  OUTS_CT  BALLS_CT  \
# 1772    ANA201605270          HOU       1            0        1         1
# 1798    ANA201605270          HOU       4            0        1         0
# 1818    ANA201605270          HOU       6            0        1         2
# 1846    ANA201605280          HOU       1            0        0         1
# 1864    ANA201605280          HOU       3            0        2         3
# ...              ...          ...     ...          ...      ...       ...
# 182809  TOR201608130          HOU       8            0        2         3
# 182820  TOR201608140          HOU       1            0        2         3
# 182838  TOR201608140          HOU       3            0        1         1
# 182863  TOR201608140          HOU       6            0        0         1
# 182876  TOR201608140          HOU       7            0        2         0
#
# Header  STRIKES_CT PITCH_SEQ_TX  AWAY_SCORE_CT  HOME_SCORE_CT  ...  \
# ...

# %%
rs_list = []
for a in range(0, len(data2016)) :
    rs = 0
    if data2016['BAT_DEST_ID'][a] > 3 :
        rs += 1
    if data2016['RUN1_DEST_ID'][a] > 3 :
        rs += 1
    if data2016['RUN2_DEST_ID'][a] > 3 :
        rs += 1
    if data2016['RUN3_DEST_ID'][a] > 3 :
        rs += 1
    rs_list.append(rs)
data2016['RUNS.SCORED'] = rs_list

# %%
data2016['RUNS.SCORED']
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 190710    0
# 190711    0
# 190712    0
# 190713    0
# 190714    0
# Name: RUNS.SCORED, Length: 190715, dtype: int64

# %%
data2016['HALF.INNING']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HALF.INNING'
#
# The above exception was the direct cause of the following exception:
#
# ...
